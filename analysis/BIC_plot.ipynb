# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
M = [[763.57,795.81,808.15,787.05,758.28],
[764.03,799.03,813.04,789.41,752.89],
[764.83,790.59,810.86,786.68,748.53],
[765.15,794.00,812.56,788.28,744.89],
[764.16,796.18,810.24,783.93,755.53],
[764.69,799.72,814.96,789.17,751.10],
[762.12,788.54,807.81,766.70,745.70],
[761.42,789.62,804.40,767.69,744.27]]

# %%
M = np.transpose(M)

# %%
M.shape
# Out:
# (5, 8)

# %%
M_Gen = [[155.35,160.39,163.49,157.40,148.15],
[155.09,160.03,163.39,157.59,146.04],
[153.66,157.08,162.23,154.52,145.89],
[154.32,156.48,162.94,154.6,143.61],
[155.28,160,163.23,156.05,147.97],
[154.75,160.28,163,156.17,146.33],
[153.16,158.02,162.16,151.52,146.98],
[154.87,158.68,159.42,151.27,145.73]]

# %%
M_Gen = np.transpose(M_Gen)

# %%
M_Gen.shape
# Out:
# (5, 8)

# %%
x = np.arange(8)
xticks = ["BS3","BSA5","BSB5", "BSAB7", "Q4", "QA6", "QB6", "QAB8"]

# %%
plt.rcParams["figure.figsize"] = (10,8)
plt.scatter(x, M[0,:],color = "green", label = "Happy", s = 100)
plt.hlines(np.min(M[0,:]),x[0]-0.5,x[7]+0.5, linestyles = "dashed",color = 'green')
plt.text(x[0]-1.7,np.min(M[0,:]),"QAB8-" + str(np.min(M[0,:])),fontsize = 12,color = "green")
plt.scatter(x, M[1,:],color = "blue", label = "Sad",marker = "^", s = 100)
plt.hlines(np.min(M[1,:]),x[0]-0.5,x[7]+0.5, linestyles = "dashed",color = 'blue')
plt.text(x[0]-1.65,np.min(M[1,:]),"QB6-" + str(np.min(M[1,:])),fontsize = 12,color = "blue")
plt.scatter(x, M[2,:],color = "red", label = "Risk",marker = "*", s = 100)
plt.hlines(np.min(M[2,:]),x[0]-0.5,x[7]+0.5, linestyles = "dashed",color = 'red')
plt.text(x[0]-1.65,np.min(M[2,:]),"QAB8-" +str(np.min(M[2,:])),fontsize = 12,color = "red")
plt.scatter(x, M[3,:],color = "orange", label = "Disgust",marker = "v", s = 100)
plt.hlines(np.min(M[3,:]),x[0]-0.5,x[7]+0.5, linestyles = "dashed",color = 'orange')
plt.text(x[0]-1.6,np.min(M[3,:]),"QB6-" + str(np.min(M[3,:])),fontsize = 12,color = "orange")
plt.scatter(x, M[4,:],color = "purple", label = "Embarass", marker = "s", s = 100)
plt.hlines(np.min(M[4,:]),x[0]-0.5,x[7]+0.5, linestyles = "dashed",color = 'purple')
plt.text(x[0]-1.7,np.min(M[4,:]),"QAB8-" +str(np.min(M[4,:])),fontsize = 12,color = "purple")
plt.xlim(x[0]-0.5,x[7]+0.5)
plt.xticks(x, xticks, fontsize = 16)
plt.yticks(fontsize = 12)
plt.ylabel("BIC",fontsize=16)
plt.locator_params(axis="y", nbins=2)
plt.xlabel("Models", fontsize=16)
plt.legend(bbox_to_anchor = (0.5, 1.035),fontsize = 14,ncol=5,loc='center')
plt.savefig("BIC_table.jpg",dpi = 500)

# %%
plt.rcParams["figure.figsize"] = (10,8)
plt.scatter(x, M_Gen[0,:],color = "green", label = "Happy", s = 100)
plt.hlines(np.min(M_Gen[0,:]),x[0]-0.5,x[7]+0.5, linestyles = "dashed",color = 'green')
plt.text(x[0]-1.5,np.min(M_Gen[0,:]),"QAB8-" + str(np.min(M_Gen[0,:])),fontsize = 10,color = "green")
plt.scatter(x, M_Gen[1,:],color = "blue", label = "Sad",marker = "^", s = 100)
plt.hlines(np.min(M_Gen[1,:]),x[0]-0.5,x[7]+0.5, linestyles = "dashed",color = 'blue')
plt.text(x[0]-1.6,np.min(M_Gen[1,:]),"BSAB7-" + str(np.min(M_Gen[1,:])),fontsize = 10,color = "blue")
plt.scatter(x, M_Gen[2,:],color = "red", label = "Risk",marker = "*", s = 100)
plt.hlines(np.min(M_Gen[2,:]),x[0]-0.5,x[7]+0.5, linestyles = "dashed",color = 'red')
plt.text(x[0]-1.5,np.min(M_Gen[2,:]),"QAB8-" +str(np.min(M_Gen[2,:])),fontsize = 10,color = "red")
plt.scatter(x, M_Gen[3,:],color = "orange", label = "Disgust",marker = "v", s = 100)
plt.hlines(np.min(M_Gen[3,:]),x[0]-0.5,x[7]+0.5, linestyles = "dashed",color = 'orange')
plt.text(x[0]-1.4,np.min(M_Gen[3,:]),"QB6-" + str(np.min(M_Gen[3,:])),fontsize = 10,color = "orange")
plt.scatter(x, M_Gen[4,:],color = "purple", label = "Embarass", marker = "s", s = 100)
plt.hlines(np.min(M_Gen[4,:]),x[0]-0.5,x[7]+0.5, linestyles = "dashed",color = 'purple')
plt.text(x[0]-1.6,np.min(M_Gen[4,:]),"BSAB7-" +str(np.min(M_Gen[4,:])),fontsize = 10,color = "purple")
plt.xlim(x[0]-0.5,x[7]+0.5)
plt.xticks(x, xticks, fontsize = 16)
plt.yticks(fontsize = 10)
plt.ylabel("Test Set G^2",fontsize=12,loc='top')
plt.locator_params(axis="y", nbins=2)
plt.xlabel("Models", fontsize=16)
plt.legend(bbox_to_anchor = (0.5, 1.035),fontsize = 14,ncol=5,loc='center')
plt.savefig("Gen_table.jpg",dpi = 500)

# %%
i = 2
color = ["green", "blue", "red", "black", "purple"]
emotion = ["Happy", "Sad", "Risky", "Disgusting", "embarassing"]
plt.rcParams["figure.figsize"] = (10,3)
plt.bar(x, M[i,:], color = color[i], label = emotion[i])
plt.ylim(np.floor(np.min(M[i,:])-10),np.ceil(1.025*np.max(M[i,:])))
plt.ylabel("BIC", fontsize = 16)
plt.xticks(x, xticks, fontsize = 16)
xlocs, xlabs = plt.xticks()
plt.yticks(np.linspace(np.floor(np.min(M[i,:])-10),np.ceil(1.025*np.max(M[i,:])),4),fontsize=13)
for j, v in enumerate(M[i,:]):
    plt.text(xlocs[j] - 0.33, v + 2, str(v), fontsize = 13)
plt.legend(fontsize = 16)
plt.savefig("bar" + str(i) + ".jpg", dpi=300)
